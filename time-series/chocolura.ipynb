# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
chocolura = pd.read_csv('../data/time_series_chocolura.csv')

# %%
def plot_comparacao(x, y1, y2, y3, dataset, title):
  sns.set_style(style='white')
  plt.figure(figsize=(14,9))
  ax = plt.subplot(3, 1,1)
  ax.set_title(title, fontsize=18, loc='left')
  sns.lineplot(x=x, y=y1, data=dataset)
  plt.subplot(3,1,2)
  sns.lineplot(x=x, y=y2, data=dataset)
  plt.subplot(3,1,3)
  sns.lineplot(x=x, y=y3, data=dataset)
  ax = ax


def showHead(dataset, number=5):
  print(dataset.head(number))

# %%
print("Quantidade de linhas e colunas {}".format(chocolura.shape))
print("Quantidade de valores nulos no geral {}".format(chocolura.isna().sum().sum()))
showHead(chocolura)
# Out:
# Quantidade de linhas e colunas (24, 2)
# Quantidade de valores nulos no geral 0
#          mes  vendas
# 0 2017-01-01     210
# 1 2017-02-01     185
# 2 2017-03-01     209
# 3 2017-04-01     280
# 4 2017-05-01     211

# %%
chocolura.mes = pd.to_datetime(chocolura.mes)
chocolura.dtypes
# Out:
# mes       datetime64[ns]
# vendas             int64
# dtype: object

# %%
# Fazendo o Diff
chocolura['aumento'] = chocolura.vendas.diff()
chocolura['aceleracao'] = chocolura.aumento.diff()
showHead(chocolura)
# Out:
#          mes  vendas  aumento  aceleracao
# 0 2017-01-01     210      NaN         NaN
# 1 2017-02-01     185    -25.0         NaN
# 2 2017-03-01     209     24.0        49.0
# 3 2017-04-01     280     71.0        47.0
# 4 2017-05-01     211    -69.0      -140.0

# %%
plot_comparacao('mes', 'vendas', 'aumento', 'aceleracao', 
                chocolura, 'Análise de Vendas Chocolura de 2017 a 2018')

# %% [markdown]
# O que é sazonalidade?
# É um padrão repetido dentro de um determinado período fixo de tempo
