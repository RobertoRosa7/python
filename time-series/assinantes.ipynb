# %%
import pandas as pd

# %%
assinantes = pd.read_csv('../data/time_series_newsletter_alucar.csv')

# %%
assinantes.head()
# Out:
#           mes  assinantes
# 0  2017-01-31           0
# 1  2017-02-28          10
# 2  2017-03-31          21
# 3  2017-04-30          34
# 4  2017-05-31          49

# %%
assinantes.dtypes
# Out:
# mes           object
# assinantes     int64
# dtype: object

# %%
print("Quantidade de linhas e colunas {}".format(assinantes.shape))
print("Quantidade de valores nulos no geral {}".format(assinantes.isna().sum().sum()))
# Out:
# Quantidade de linhas e colunas (24, 2)
# Quantidade de valores nulos no geral 0

# %%
assinantes['mes'] = pd.to_datetime(assinantes['mes'])
assinantes.dtypes
# Out:
# mes           datetime64[ns]
# assinantes             int64
# dtype: object

# %%
assinantes['aumento'] = assinantes['assinantes'].diff()
assinantes['aceleracao'] = assinantes['aumento'].diff()
assinantes.head()
# Out:
#          mes  assinantes  aumento  aceleracao
# 0 2017-01-31           0      NaN         NaN
# 1 2017-02-28          10     10.0         NaN
# 2 2017-03-31          21     11.0         1.0
# 3 2017-04-30          34     13.0         2.0
# 4 2017-05-31          49     15.0         2.0

# %%
import seaborn as sns
from matplotlib import pyplot as plt

def plot_comparacao(x, y1, y2, y3, dataset, title):
  plt.figure(figsize=(16,12))
  ax = plt.subplot(3, 1,1)
  ax.set_title(title, fontsize=18, loc='left')
  sns.lineplot(x=x, y=y1, data=dataset)
  plt.subplot(3,1,2)
  sns.lineplot(x=x, y=y2, data=dataset)
  plt.subplot(3,1,3)
  sns.lineplot(x=x, y=y3, data=dataset)
  ax = ax

# %%
plot_comparacao('mes', 'assinantes', 'aumento', 'aceleracao', 
                assinantes, 'Análise de assinantes da newletters')
