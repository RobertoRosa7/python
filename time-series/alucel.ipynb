# %%
import os, sys
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
import pandas as pd
from utils.utils import Utils

# %%
alucel = pd.read_csv('../data/time_series_alucel.csv')
utils = Utils()

# %%
alucel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   dia     61 non-null     object
#  1   vendas  61 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 1.1+ KB

# %%
utils.show_line_and_columns(alucel)
utils.show_data_none(alucel)
print(alucel.dtypes)
print(alucel.head())
# Out:
# Quantidade de linhas e colunas (61, 2)
# Quantidade de dados nulos 0
# dia        object
# vendas    float64
# dtype: object
#           dia   vendas
# 0  2018-10-01  1374.83
# 1  2018-10-02  2185.69
# 2  2018-10-03  1860.36
# 3  2018-10-04  1939.02
# 4  2018-10-05  1946.17

# %%
alucel['dia'] = pd.to_datetime(alucel.dia)
print(alucel.dtypes)
# Out:
# dia       datetime64[ns]
# vendas           float64
# dtype: object

# %%
utils.plotar('dia', 'vendas', alucel, 'Análise de Vendas Alucel de 2017 e 2018', 'Tempo', 'Vendas')
# Out:
# 'dia'

# %%
alucel['aumento'] = alucel.vendas.diff()
alucel['aceleracao'] = alucel.aumento.diff()
alucel.head()
# Out:
#          dia   vendas  aumento  aceleracao
# 0 2018-10-01  1374.83      NaN         NaN
# 1 2018-10-02  2185.69   810.86         NaN
# 2 2018-10-03  1860.36  -325.33    -1136.19
# 3 2018-10-04  1939.02    78.66      403.99
# 4 2018-10-05  1946.17     7.15      -71.51

# %%
utils.plot_comparacao('dia', 'vendas', 'aumento', 'aceleracao', alucel, 'Análise de Vendas da Alucel de Outubro e Novembro de 2018')
# Out:
# <AxesSubplot:title={'left':'Análise de Vendas da Alucel de Outubro e Novembro de 2018'}, xlabel='dia', ylabel='vendas'>

# %%
alucel['media_movel'] = utils.buscar_media_movel(alucel.vendas, 21)
alucel.head(21)
# Out:
#           dia   vendas  aumento  aceleracao  media_movel
# 0  2018-10-01  1374.83      NaN         NaN          NaN
# 1  2018-10-02  2185.69   810.86         NaN          NaN
# 2  2018-10-03  1860.36  -325.33    -1136.19          NaN
# 3  2018-10-04  1939.02    78.66      403.99          NaN
# 4  2018-10-05  1946.17     7.15      -71.51          NaN
# 5  2018-10-06  2005.89    59.72       52.57          NaN
# 6  2018-10-07  3793.07  1787.18     1727.46          NaN
# 7  2018-10-08  2039.59 -1753.48    -3540.66          NaN
# 8  2018-10-09  3365.58  1325.99     3079.47          NaN
# 9  2018-10-10  2616.12  -749.46    -2075.45          NaN
# 10 2018-10-11  3745.49  1129.37     1878.83          NaN
# 11 2018-10-12  1578.37 -2167.12    -3296.49          NaN
# 12 2018-10-13  4075.13  2496.76     4663.88          NaN
# 13 2018-10-14  2183.18 -1891.95    -4388.71          NaN
# 14 2018-10-15  3025.13   841.95     2733.90          NaN
# ...

# %%
utils.plotar('dia', 'media_movel', alucel, 'Análise de vendas com média móvel de 21 dias', 'Tempo', 'Média Móvel')
# Out:
# 'dia'
