# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
passageiros = pd.read_csv("../data/files/passageiros.csv")
passageiros.head()
# Out:
#          tempo  passageiros
# 0  1949.000000          112
# 1  1949.083333          118
# 2  1949.166667          132
# 3  1949.250000          129
# 4  1949.333333          121

# %%
mpl.rcParams['figure.figsize'] = (24, 6)
mpl.rcParams['font.size'] = 18

# %%
sns.lineplot(x='tempo', y='passageiros',
             data=passageiros, label="Dados Completos")
# Out:
# <AxesSubplot:xlabel='tempo', ylabel='passageiros'>

# %%
sc = StandardScaler()
sc.fit(passageiros)
# Out:
# StandardScaler()

# %%
dados_escalados = sc.transform(passageiros)

# %%
x, y = dados_escalados[:, 0], dados_escalados[:, 1]

# %%
sns.lineplot(x=x, y=y, label="Dados Escalados")
plt.ylabel('Passageiros')
plt.xlabel('Data')
# Out:
# Text(0.5, 0, 'Data')

# %%
tamanho_treino = int(len(passageiros)*0.9)
tamanho_teste = len(passageiros) - tamanho_treino

# %%
x_treino = x[0:tamanho_treino]
y_treino = y[0:tamanho_treino]

x_teste = x[tamanho_treino:len(passageiros)]
y_teste = y[tamanho_treino:len(passageiros)]

# %%
sns.lineplot(x=x_treino, y=y_treino, label="Treino")
sns.lineplot(x=x_teste, y=y_teste, label="Teste")
plt.ylabel('Passageiros')
plt.xlabel('Data')
# Out:
# Text(0.5, 0, 'Data')

# %%
regressor = Sequential()

# %%
regressor.add(Dense(1, input_dim=1, kernel_initializer='Ones',
              use_bias=False, activation="linear"))

# %%
regressor.compile(loss='mean_squared_error', optimizer="adam", metrics=['accuracy'])

# %%
regressor.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 1)                 1
#
# =================================================================
# Total params: 1
# Trainable params: 1
# Non-trainable params: 0
# _________________________________________________________________

# %%
regressor.get_config()
# Out:
# {'name': 'sequential_2',
#  'layers': [{'class_name': 'InputLayer',
#    'config': {'batch_input_shape': (None, 1),
#     'dtype': 'float32',
#     'sparse': False,
#     'ragged': False,
#     'name': 'dense_4_input'}},
#   {'class_name': 'Dense',
#    'config': {'name': 'dense_4',
#     'trainable': True,
#     'batch_input_shape': (None, 1),
#     'dtype': 'float32',
#     'units': 1,
#     'activation': 'linear',
#     'use_bias': False,
#     'kernel_initializer': {'class_name': 'Ones', 'config': {}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None}}]}

# %%
regressor.fit(x_treino, y_treino)
# Out:
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1284 - accuracy: 0.0000e+00

# %%
y_predict = regressor.predict(x_treino)
# Out:
# 5/5 [==============================] - 0s 2ms/step

# %%
sns.lineplot(x=x_treino, y=y_treino, label="Treino")
sns.lineplot(x=x_treino, y=y_predict[:,0], label="Ajuste Treino")
# Out:
# <AxesSubplot:>

# %%
tmp = {'tempo': x_treino, 'passageiros': y_predict[:, 0]}
resultados = pd.DataFrame(data=tmp)

# %%
resultado_transf = sc.inverse_transform(resultados)
resultado_transf = pd.DataFrame(resultado_transf)
resultado_transf.columns = ['tempo', 'passageiros']

# %%
sns.lineplot(x='tempo', y='passageiros', data=passageiros, label="Dados Completos")
sns.lineplot(x='tempo', y='passageiros', data=resultado_transf, label="Ajuste Treino")
# Out:
# <AxesSubplot:xlabel='tempo', ylabel='passageiros'>

# %%
y_predict_teste = regressor.predict(x_teste)
tmp = {'tempo': x_teste, 'passageiros': y_predict_teste[:, 0]}
resultado_testes = pd.DataFrame(data=tmp)
resultado_testes = sc.inverse_transform(resultado_testes)
resultado_testes = pd.DataFrame(resultado_testes)
resultado_testes.columns = ['tempo', 'passageiros']
# Out:
# 1/1 [==============================] - 0s 35ms/step

# %%
sns.lineplot(x='tempo', y='passageiros',
             data=passageiros, label="Dados Completos")
sns.lineplot(x='tempo', y='passageiros',
             data=resultado_transf, label="Ajuste Treino")
sns.lineplot(x='tempo', y='passageiros',
             data=resultado_testes, label="Resultado Previsto")
# Out:
# <AxesSubplot:xlabel='tempo', ylabel='passageiros'>

# %%
regressor2 = Sequential()

# %%
regressor2.add(Dense(8, input_dim=1,kernel_initializer="random_uniform", activation='sigmoid', use_bias=False))
regressor2.add(Dense(8, input_dim=1,kernel_initializer="random_uniform", activation='sigmoid', use_bias=False))
regressor2.add(Dense(1, input_dim=1,kernel_initializer="random_uniform", activation='linear', use_bias=False))

# %%
regressor2.compile(loss='mean_squared_error', optimizer='adam')

# %%
regressor2.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 8)                 8
#
#  dense_9 (Dense)             (None, 8)                 64
#
#  dense_10 (Dense)            (None, 1)                 8
#
# =================================================================
# Total params: 80
# Trainable params: 80
# Non-trainable params: 0
# _________________________________________________________________

# %%
regressor2.fit(x_treino, y_treino, epochs=200)
# Out:
# Epoch 1/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.8191
# Epoch 2/200
# 5/5 [==============================] - 0s 7ms/step - loss: 0.8123
# Epoch 3/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.8074
# Epoch 4/200
# 5/5 [==============================] - 0s 7ms/step - loss: 0.8034
# Epoch 5/200
# 5/5 [==============================] - 0s 7ms/step - loss: 0.8005
# Epoch 6/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7978
# Epoch 7/200
# 5/5 [==============================] - 0s 7ms/step - loss: 0.7948
# Epoch 8/200
# 5/5 [==============================] - 0s 7ms/step - loss: 0.7924
# Epoch 9/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.7890
# Epoch 10/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.7864
# Epoch 11/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7850
# Epoch 12/200
# 5/5 [==============================] - 0s 12ms/step - loss: 0.7825
# Epoch 13/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7810
# Epoch 14/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.7797
# Epoch 15/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.7796
# Epoch 16/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7789
# Epoch 17/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7788
# Epoch 18/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7787
# Epoch 19/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7787
# Epoch 20/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7786
# Epoch 21/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7783
# Epoch 22/200
# 5/5 [==============================] - 0s 7ms/step - loss: 0.7783
# Epoch 23/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.7784
# Epoch 24/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.7784
# Epoch 25/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.7784
# Epoch 26/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.7787
# Epoch 27/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.7785
# Epoch 28/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.7782
# Epoch 29/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7781
# Epoch 30/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.7777
# Epoch 31/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.7778
# Epoch 32/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7775
# Epoch 33/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.7775
# Epoch 34/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.7773
# Epoch 35/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7781
# Epoch 36/200
# 5/5 [==============================] - 0s 7ms/step - loss: 0.7778
# Epoch 37/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.7776
# Epoch 38/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.7783
# Epoch 39/200
# 5/5 [==============================] - 0s 7ms/step - loss: 0.7792
# Epoch 40/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.7792
# Epoch 41/200
# 5/5 [==============================] - 0s 7ms/step - loss: 0.7797
# Epoch 42/200
# 5/5 [==============================] - 0s 7ms/step - loss: 0.7801
# Epoch 43/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.7799
# Epoch 44/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.7803
# Epoch 45/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7811
# Epoch 46/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7816
# Epoch 47/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.7810
# Epoch 48/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7800
# Epoch 49/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.7785
# Epoch 50/200
# 5/5 [==============================] - 0s 7ms/step - loss: 0.7780
# Epoch 51/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.7778
# Epoch 52/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.7776
# Epoch 53/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.7769
# Epoch 54/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.7760
# Epoch 55/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7751
# Epoch 56/200
# 5/5 [==============================] - 0s 7ms/step - loss: 0.7744
# Epoch 57/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7737
# Epoch 58/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.7735
# Epoch 59/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.7731
# Epoch 60/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.7726
# Epoch 61/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.7723
# Epoch 62/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.7718
# Epoch 63/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.7716
# Epoch 64/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.7713
# Epoch 65/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.7709
# Epoch 66/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.7708
# Epoch 67/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.7706
# Epoch 68/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.7701
# Epoch 69/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.7700
# Epoch 70/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.7696
# Epoch 71/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.7694
# Epoch 72/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.7694
# Epoch 73/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.7688
# Epoch 74/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.7685
# Epoch 75/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7680
# Epoch 76/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.7673
# Epoch 77/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7669
# Epoch 78/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7665
# Epoch 79/200
# 5/5 [==============================] - 0s 7ms/step - loss: 0.7658
# Epoch 80/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.7655
# Epoch 81/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7655
# Epoch 82/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.7649
# Epoch 83/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7642
# Epoch 84/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7639
# Epoch 85/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7633
# Epoch 86/200
# 5/5 [==============================] - 0s 7ms/step - loss: 0.7629
# Epoch 87/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7623
# Epoch 88/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7615
# Epoch 89/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7608
# Epoch 90/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7613
# Epoch 91/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7603
# Epoch 92/200
# 5/5 [==============================] - 0s 15ms/step - loss: 0.

# Out:
# 1/1 [==============================] - 0s 26ms/step

# %%
sns.lineplot(x=x_treino, y=y_treino, label="Treino")
sns.lineplot(x=x_teste, y=y_teste, label="Teste")
sns.lineplot(x=x_treino, y=y_predict[:,0], label="Ajuste Treino")
sns.lineplot(x=x_teste, y=y_predict_teste[:,0], label="Previsão")
# Out:
# <AxesSubplot:>

# %%
vetor = pd.DataFrame(y_treino)[0]

# %%
def separa_dados(vetor, n_passos):
    x_novo, y_novo = [], []

    for i in range(n_passos, vetor.shape[0]):
        x_novo.append(list(vetor.loc[i - n_passos:i - 1]))
        y_novo.append(vetor.loc[i])

    x_novo, y_novo = np.array(x_novo), np.array(y_novo)
    return x_novo, y_novo

# %%
x_treino_novo, y_treino_novo = separa_dados(vetor, 1)

# %%
x_treino_novo[0:5]
# Out:
# array([[-1.40777884],
#        [-1.35759023],
#        [-1.24048348],
#        [-1.26557778],
#        [-1.33249593]])

# %%
vetor2 = pd.DataFrame(y_teste)[0]

# %%
x_teste_novo, y_teste_novo = separa_dados(vetor2, 1)

# %%
regressor3 = Sequential()

# %%
regressor3.add(Dense(8, input_dim=1, kernel_initializer="Ones",
               activation='linear', use_bias=False))
regressor3.add(Dense(64, input_dim=1, kernel_initializer="random_uniform",
                     activation='sigmoid', use_bias=False))
regressor3.add(Dense(1, input_dim=1, kernel_initializer="random_uniform",
                     activation='linear', use_bias=False))

# %%
regressor3.compile(loss="mean_squared_error", optimizer='adam')

# %%
regressor3.fit(x_treino_novo, y_treino_novo, epochs=100)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7883
# Epoch 2/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6370
# Epoch 3/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.5072
# Epoch 4/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3874
# Epoch 5/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2923
# Epoch 6/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2114
# Epoch 7/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1572
# Epoch 8/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1165
# Epoch 9/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0954
# Epoch 10/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0868
# Epoch 11/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0863
# Epoch 12/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0845
# Epoch 13/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0863
# Epoch 14/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0859
# Epoch 15/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0848
# Epoch 16/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0834
# Epoch 17/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0815
# Epoch 18/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0813
# Epoch 19/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0794
# Epoch 20/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0783
# Epoch 21/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0777
# Epoch 22/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0771
# Epoch 23/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0764
# Epoch 24/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0757
# Epoch 25/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0750
# Epoch 26/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0743
# Epoch 27/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0738
# Epoch 28/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0734
# Epoch 29/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0727
# Epoch 30/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0722
# Epoch 31/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0720
# Epoch 32/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0717
# Epoch 33/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0712
# Epoch 34/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0706
# Epoch 35/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0704
# Epoch 36/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0698
# Epoch 37/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0696
# Epoch 38/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0692
# Epoch 39/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0689
# Epoch 40/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0686
# Epoch 41/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0684
# Epoch 42/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0682
# Epoch 43/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0679
# Epoch 44/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0677
# Epoch 45/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0676
# Epoch 46/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0673
# Epoch 47/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0672
# Epoch 48/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0670
# Epoch 49/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0668
# Epoch 50/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0666
# Epoch 51/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0666
# Epoch 52/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0666
# Epoch 53/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0662
# Epoch 54/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0669
# Epoch 55/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0660
# Epoch 56/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0659
# Epoch 57/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0662
# Epoch 58/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0659
# Epoch 59/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0660
# Epoch 60/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0655
# Epoch 61/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0657
# Epoch 62/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0652
# Epoch 63/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0653
# Epoch 64/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0656
# Epoch 65/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0653
# Epoch 66/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0650
# Epoch 67/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0650
# Epoch 68/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0653
# Epoch 69/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0649
# Epoch 70/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0648
# Epoch 71/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0647
# Epoch 72/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0647
# Epoch 73/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0651
# Epoch 74/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0645
# Epoch 75/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0647
# Epoch 76/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0649
# Epoch 77/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0650
# Epoch 78/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0643
# Epoch 79/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0648
# Epoch 80/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0642
# Epoch 81/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0646
# Epoch 82/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0643
# Epoch 83/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0645
# Epoch 84/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0641
# Epoch 85/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0641
# Epoch 86/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0649
# Epoch 87/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0640
# Epoch 88/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0643
# Epoch 89/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0640
# Epoch 90/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0643
# Epoch 91/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0641
# Epoch 92/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0640
# Epoch 93/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0638
# Epoch 94/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0639
# Epoch 95/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0639
# Epoch 96/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0639
# Epoch 97/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0637
# Epoch 98/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0637
# Epoch 99/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0637
# Epoch 100/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0637

# %%
y_predict_novo = regressor3.predict(x_treino_novo)
# Out:
# 4/4 [==============================] - 0s 4ms/step

# %%
sns.lineplot(x='tempo', y=y_treino_novo, data=passageiros[1:129], label="Treino")
sns.lineplot(x='tempo', y=pd.DataFrame(y_predict_novo)[0], data=passageiros[1:129], label="Ajuste Treino")
# Out:
# <AxesSubplot:xlabel='tempo', ylabel='0'>
