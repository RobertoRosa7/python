# %% [markdown]
# ## Import Dependencies

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading data

# %%
base_file = os.path.join(os.getcwd(), '..', 'data', 'files')

# %%
df = pd.read_excel(os.path.join(base_file, 'mega_sena_clean_data.xlsx'))

# %%
df.shape
# Out:
# (2560, 8)

# %%
df.head()
# Out:
#    Concurso        Data  bola 1  bola 2  bola 3  bola 4  bola 5  bola 6
# 0      2560  01/02/2023       4       5      17      20      48      52
# 1      2559  28/01/2023      12      32      35      20       9      30
# 2      2558  25/01/2023      10      25      34       2      18      44
# 3      2557  21/01/2023      13       3      27      25      16      33
# 4      2556  18/01/2023      34      10      14       2       6      56

# %%
df['Data'] = pd.to_datetime(df.Data, format="%d/%m/%Y")
df.head()
# Out:
#    Concurso       Data  bola 1  bola 2  bola 3  bola 4  bola 5  bola 6
# 0      2560 2023-02-01       4       5      17      20      48      52
# 1      2559 2023-01-28      12      32      35      20       9      30
# 2      2558 2023-01-25      10      25      34       2      18      44
# 3      2557 2023-01-21      13       3      27      25      16      33
# 4      2556 2023-01-18      34      10      14       2       6      56

# %%
df.tail()
# Out:
#       Concurso       Data  bola 1  bola 2  bola 3  bola 4  bola 5  bola 6
# 2555         5 1996-04-08       1      19      46       6      16       2
# 2556         4 1996-04-01       6      59      42      27       1       5
# 2557         3 1996-03-25      36      30      10      11      29      47
# 2558         2 1996-03-18       9      39      37      49      43      41
# 2559         1 1996-03-11      41       5       4      52      30      33

# %%
# Plotando um gráfico de barras com a frequência de cada número sorteado
plt.figure(figsize=(24, 6))
plt.hist(df['bola 1'], bins=60, range=(1, 60), color='blue', alpha=0.5, label="bola 1")
plt.hist(df['bola 2'], bins=60, range=(1, 60), color='red', alpha=0.5, label="bola 2")
plt.hist(df['bola 3'], bins=60, range=(1, 60), color='green', alpha=0.5, label="bola 3")
plt.hist(df['bola 4'], bins=60, range=(1, 60), color='yellow', alpha=0.5, label="bola 4")
plt.hist(df['bola 5'], bins=60, range=(1, 60), color='purple', alpha=0.5, label="bola 5")
plt.hist(df['bola 6'], bins=60, range=(1, 60), color='orange', alpha=0.5, label="bola 6")
plt.legend()
plt.xlabel('Número')
plt.ylabel('Frequência')
plt.title('Frequência de Números Sorteados na Mega Sena')

plt.show()

# %%
ball_1 = df['bola 1'].value_counts()
ball_1  = ball_1.reset_index()
ball_1 = ball_1.rename(columns={'bola 1': 'frequencia', 'index': 'dezena'})
ball_1.head(20)
# Out:
#     dezena  frequencia
# 0       28          60
# 1        4          57
# 2       49          54
# 3       32          53
# 4       35          52
# 5       47          52
# 6       30          51
# 7       25          50
# 8       44          50
# 9       20          50
# 10       2          49
# 11      53          49
# 12      13          48
# 13      19          48
# 14      59          48
# 15      11          47
# 16      38          47
# 17      46          47
# 18      17          47
# 19       6          46

# %%
ball_2 = df['bola 2'].value_counts()
ball_2  = ball_2.reset_index()
ball_2 = ball_2.rename(columns={'bola 2': 'frequencia', 'index': 'dezena'})
ball_2.head(20)
# Out:
#     dezena  frequencia
# 0        5          62
# 1       10          58
# 2       32          56
# 3       53          55
# 4        8          54
# 5       39          53
# 6       49          52
# 7       42          52
# 8       11          52
# 9       21          52
# 10      17          52
# 11      41          51
# 12       3          50
# 13      56          50
# 14       6          48
# 15      43          47
# 16      33          47
# 17      37          45
# 18      26          45
# 19       1          44

# %%
ball_3 = df['bola 3'].value_counts()
ball_3 = ball_3.reset_index()
ball_3 = ball_3.rename(columns={'bola 3': 'frequencia', 'index': 'dezena'})
ball_3.head(20)
# Out:
#     dezena  frequencia
# 0       27          58
# 1       56          54
# 2       18          53
# 3       58          53
# 4       41          52
# 5       38          51
# 6       34          50
# 7       24          50
# 8        4          50
# 9       37          49
# 10      30          49
# 11       1          49
# 12      23          49
# 13      54          49
# 14      29          49
# 15       2          48
# 16      51          47
# 17      12          47
# 18      19          47
# 19      35          46

# %%
ball_4 = df['bola 4'].value_counts()
ball_4 = ball_4.reset_index()
ball_4 = ball_4.rename(columns={'bola 4': 'frequencia', 'index': 'dezena'})
ball_4.head(20)
# Out:
#     dezena  frequencia
# 0       37          59
# 1       29          58
# 2       60          52
# 3       36          50
# 4       10          50
# 5       53          50
# 6       18          50
# 7       43          50
# 8       54          49
# 9       25          48
# 10       5          48
# 11       1          48
# 12      28          48
# 13      41          48
# 14      44          47
# 15      34          47
# 16      23          47
# 17      33          46
# 18      11          46
# 19      31          45

# %%
ball_5 = df['bola 5'].value_counts()
ball_5 = ball_5.reset_index()
ball_5 = ball_5.rename(columns={'bola 5': 'frequencia', 'index': 'dezena'})
ball_5.head(20)
# Out:
#     dezena  frequencia
# 0       35          61
# 1       45          55
# 2       16          53
# 3       10          53
# 4       44          52
# 5       33          51
# 6       38          50
# 7       34          50
# 8       28          49
# 9       52          49
# 10      12          49
# 11      24          49
# 12      42          47
# 13      14          47
# 14      36          47
# 15      47          47
# 16      53          45
# 17      13          45
# 18      46          45
# 19       9          45

# %%
ball_6 = df['bola 6'].value_counts()
ball_6 = ball_6.reset_index()
ball_6 = ball_6.rename(columns={'bola 6': 'frequencia', 'index': 'dezena'})
ball_6.shape
# Out:
# (60, 2)

# %%
balls = pd.concat([ball_1, ball_2, ball_3, ball_4, ball_5, ball_6], axis=0)
balls = balls.reset_index()
balls = balls.drop(columns=['index'])
# balls.sort_values(by=['frequencia'], ascending=False)
balls
# Out:
#      dezena  frequencia
# 0        28          60
# 1         4          57
# 2        49          54
# 3        32          53
# 4        35          52
# ..      ...         ...
# 355      47          35
# 356      59          34
# 357      35          34
# 358      28          33
# 359      21          30
#
# [360 rows x 2 columns]

# %%
all_balls = balls['dezena'].value_counts()
all_balls = all_balls.reset_index()
all_balls.head(6)
# Out:
#    index  dezena
# 0     28       6
# 1      4       6
# 2     33       6
# 3     29       6
# 4     37       6
# 5      9       6

# %%
plt.figure(figsize=(24, 6))
plt.hist(balls['frequencia'], bins=60, range=(1, 60), color='purple', alpha=0.6, label="Frequência", rwidth=0.8)
plt.legend()
plt.xlabel('Números')
plt.ylabel('Frequência')
plt.title('Frequência de Números Sorteados na Mega Sena')

plt.show()

# %%
df2 = df.drop(columns=['Concurso', 'Data'])

# %%
sorteios = []
for cols in df2.loc[:].values:
    cols.sort()
    d = ' '.join([str(n) for n in list(cols)])
    sorteios.append(d)

# %%
df['Sorteios'] = sorteios
df.head(12)
# Out:
#     Concurso       Data  bola 1  bola 2  bola 3  bola 4  bola 5  bola 6  \
# 0       2560 2023-02-01       4       5      17      20      48      52
# 1       2559 2023-01-28      12      32      35      20       9      30
# 2       2558 2023-01-25      10      25      34       2      18      44
# 3       2557 2023-01-21      13       3      27      25      16      33
# 4       2556 2023-01-18      34      10      14       2       6      56
# 5       2555 2023-01-14      45      58       3      20      52      53
# 6       2554 2023-01-12      43      19      25      44      48      49
# 7       2553 2023-01-10      58      54      15      55      13      53
# 8       2552 2023-01-07      24      38      41       5      33      25
# 9       2551 2023-01-04      25      43      46      48       1      29
# 10      2550 2022-12-31      59      34       4      58      10       5
# 11      2549 2022-12-17      30      10      33       1       6      35
#
#              Sorteios
# ...

# %%
query = """ Sorteios == '13 15 53 54 55 58' """
df.query(query)
# Out:
#    Concurso       Data  bola 1  bola 2  bola 3  bola 4  bola 5  bola 6  \
# 7      2553 2023-01-10      58      54      15      55      13      53
#
#             Sorteios
# 7  13 15 53 54 55 58

# %%
df['Sorteios'].value_counts()
# Out:
# 4 5 17 20 48 52      1
# 9 12 20 30 32 35     1
# 4 18 23 31 37 54     1
# 2 3 17 49 50 59      1
# 11 15 40 41 42 47    1
#                     ..
# 12 31 34 36 48 56    1
# 25 27 29 37 50 51    1
# 1 7 11 32 51 59      1
# 3 23 26 35 39 49     1
# 4 5 30 33 41 52      1
# Name: Sorteios, Length: 2560, dtype: int64
